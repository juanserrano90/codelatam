# %%
import sys
from os.path import isfile
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
from scipy import stats
import random
import logging
from add_spikes import add_spikes
from shift_spectrum import shift_spectrum
from get_redshift import get_redshift
import os

# %%
# -- Logging info
logging.basicConfig(filename='modifications.txt', level=logging.INFO,
                    format='%(asctime)s - %(message)s', filemode='w')

# %%
def modify(spectrum, sn_name, delay_phase):
    # --Error handling
    if not isinstance(spectrum, np.ndarray):
        raise TypeError(f"Error: Expected 'np.ndarray', got {type(spectrum).__name__}")
    if not isinstance(sn_name, str):
        raise TypeError(f"Error: Expected 'str', got {type(sn_name).__name__}")
    if not isinstance(delay_phase, float):
        raise TypeError(f"Error: Expected 'float', got {type(delay_phase).__name__}")

    # --Copy spectrum and log basic information
    modified_spectrum = spectrum.copy()
    logging.info(f'Object: {sn_name}, phase delay: {delay_phase}')

    # --Prepare modification details
    modification_details = {
        'Object': sn_name,
        'Phase Delay': delay_phase,
        'Modification Type': '',
        'Redshift Applied': False,
        'Spikes Added': False
    }

    # --Apply modifications
    modifications = random.randint(0, 3)
    if modifications == 0:
        logging.info('---Modifications: None')
        modification_details['Modification Type'] = 'None'
    else:
        try:
            redshift = get_redshift(sn_name)  # Intentar obtener el redshift
            modification_details['Redshift Applied'] = True
        except Exception as e:
            logging.warning(f"Warning: No se encontró redshift para {sn_name}. Detalle: {e}")
            redshift = 0.001  # Valor de redshift alternativo si no se encuentra el original
            logging.info(f'Usando redshift alternativo: {redshift}')

        if modifications == 1:
            logging.info('---Modifications: Shift spectra on x axis only')
            modified_spectrum = shift_spectrum(spectrum, redshift)
            modification_details['Modification Type'] = 'Shift Spectrum'
        elif modifications == 2:
            logging.info('---Modifications: Add spikes only')
            modified_spectrum = add_spikes(spectrum, redshift)
            modification_details['Modification Type'] = 'Add Spikes'
            modification_details['Spikes Added'] = True
        elif modifications == 3:
            logging.info('---Modifications: Shift spectra on x axis AND add spikes')
            modified_spectrum = add_spikes(shift_spectrum(spectrum, redshift), redshift)
            modification_details['Modification Type'] = 'Shift and Add Spikes'
            modification_details['Spikes Added'] = True

    # Convert details dictionary to a DataFrame
    modification_table = pd.DataFrame([modification_details])

    return modified_spectrum, modification_table

# %%
np.random.seed(3312)
url = "https://github.com/juanserrano90/codelatam/raw/main/Data/data/sn_data.parquet"
df_raw = pd.read_parquet(url)
wavelength = np.array([float(c) for c in df_raw.columns[5:]])
column_names = df_raw.columns.values.tolist()
column_names = np.array(column_names[5:]).astype(float)

# %%
data_aumentation_plan = pd.DataFrame(columns=['Type', 'N° of Copys'])

data_aumentation_plan['Type'] = ['Ia-91T', 'Ia-91bg', 'Ia-pec']
data_aumentation_plan['N° of Copys'] = [172, 306 , 500]

# %%
df_raw['SN Subtype'].value_counts()
# Out:
# Ia-norm     2387
# Ia-91T       398
# IIb          328
# Ic-broad     279
# Ib-norm      270
# Ia-91bg      264
# Ic-norm      263
# II-pec       241
# IIP          176
# Ia-pec       141
# Iax           68
# IIn           64
# Ic-pec        33
# Ibn           31
# Ia-csm        30
# Ib-pec        15
# IIL           13
# Name: SN Subtype, dtype: int64

# %%
#np.random.seed(1)

modified = []
modification_tables = []


for i in data_aumentation_plan['Type']:
    print(f"Procesando tipo: {i}")
    
    # Selecciona el subtipo a aumentar
    df_loc = df_raw[df_raw['SN Subtype'] == i]
    
    # Selecciona el número de copias necesarias
    n = data_aumentation_plan[data_aumentation_plan['Type'] == i]['N° of Copys'].values[0]

    # Bucle para asegurar el número de copias deseado
    while len(modification_tables) < n:
        # Selecciona una muestra
        df_loc_sampled = df_loc.sample(n=1, replace=True)
        
        # Aplica las modificaciones:
        for index, row in df_loc_sampled.iterrows():
            sn_name = index
            try:
                # Obtiene el valor de 'Spectral Phase'
                delay_phases = row['Spectral Phase']
                
                # Intenta obtener la muestra correspondiente de df_raw
                sample = df_raw.loc[(df_raw.index == sn_name)].iloc[:, 5:].values[0]

                # Modifica el espectro y guarda la tabla de modificaciones
                mod_spectrum, mod_table = modify(sample, sn_name, delay_phases)
                modified.append(mod_spectrum)
                modification_tables.append(mod_table)

            except IndexError as e:
                print(f"Error: No se encontró un valor para la supernova {sn_name}. Detalle: {e}")
            except KeyError as e:
                print(f"Error: Columna no encontrada en la fila de {sn_name}. Detalle: {e}")
            except Exception as e:
                print(f"Error inesperado para {sn_name}. Detalle: {e}")
# Out:
# Procesando tipo: Ia-91T
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009023560950071606
# Wavelength shift: 5.640431142761786 Å
# Pixel shift: 0
# Error inesperado para sn2003fa. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001069649586926174
# Wavelength shift: 6.686146273431883 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.000988453231807925
# Wavelength shift: 6.178605566806432 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009618284606940127
# Wavelength shift: 6.012179929532243 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010964197947076822
# Wavelength shift: 6.8534810035949505 Å
# Pixel shift: 0
# Error inesperado para sn1999aa. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010458209423818204
# Wavelength shift: 6.537198613498687 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009490346467168428
# Wavelength shift: 5.932208588738055 Å
# Pixel shift: 0
# Error inesperado para sn2003fa. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.000989921358873781
# Wavelength shift: 6.1877825088912735 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010519952320104733
# Wavelength shift: 6.575792751332497 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010474001776656309
# Wavelength shift: 6.547070068820859 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010992240888327673
# Wavelength shift: 6.871010034544166 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010991777818256593
# Wavelength shift: 6.87072057954246 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001021534865830578
# Wavelength shift: 6.385391645858005 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001022207906437344
# Wavelength shift: 6.389598675898308 Å
# Pixel shift: 0
# Error inesperado para sn1999aw. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010352155705461025
# Wavelength shift: 6.4709067472235695 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009012096951209229
# Wavelength shift: 5.633265247106876 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010950015869711208
# Wavelength shift: 6.844616096349942 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009747219625859063
# Wavelength shift: 6.092774397739073 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009795621199212862
# Wavelength shift: 6.123029165586712 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001099595832339478
# Wavelength shift: 6.873333722126011 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010872715034380299
# Wavelength shift: 6.7962970301437675 Å
# Pixel shift: 0
# Error inesperado para sn2001V. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009292639769735862
# Wavelength shift: 5.808626444227535 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010827881093719103
# Wavelength shift: 6.768272311680915 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010194075674179956
# Wavelength shift: 6.37209436745243 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009405801692422404
# Wavelength shift: 5.879361493996431 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010495114785014018
# Wavelength shift: 6.560267349862915 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001086264058030812
# Wavelength shift: 6.789999708630734 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009185157451507235
# Wavelength shift: 5.741441591331055 Å
# Pixel shift: 0
# Error inesperado para sn1999dq. Detalle: local variable 'spike_loc' referenced before assignment
# Error inesperado para sn1999ac. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010396813308544582
# Wavelength shift: 6.498821240912625 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009981766489526736
# Wavelength shift: 6.239384526665808 Å
# Pixel shift: 0
# Error inesperado para sn1991T. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001067823532035773
# Wavelength shift: 6.674732002581162 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009219611850864971
# Wavelength shift: 5.762978284906665 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010166196915993495
# Wavelength shift: 6.3546679637558725 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010567425844479165
# Wavelength shift: 6.605467416004218 Å
# Pixel shift: 0
# Error inesperado para sn1997br. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009602966712546736
# Wavelength shift: 6.00260504783575 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009131053071016718
# Wavelength shift: 5.70762212312254 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009400685356894584
# Wavelength shift: 5.876163384247118 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009205390238675116
# Wavelength shift: 5.754088665305292 Å
# Pixel shift: 0
# Error inesperado para sn1991T. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.000964873801018594
# Wavelength shift: 6.031215687701461 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010537319459934635
# Wavelength shift: 6.586648571656568 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.000946132454730612
# Wavelength shift: 5.9140676196106945 Å
# Pixel shift: 0
# Error inesperado para sn2001V. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010599317577312634
# Wavelength shift: 6.6254022426281916 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009978258403232016
# Wavelength shift: 6.237191698435609 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010764702700290871
# Wavelength shift: 6.7287808758925385 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010656118612553903
# Wavelength shift: 6.660907330906386 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.000986301826263121
# Wavelength shift: 6.165157599975192 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009217428158837064
# Wavelength shift: 5.761613306647133 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001078744222165579
# Wavelength shift: 6.742994854740564 Å
# Pixel shift: 0
# Error inesperado para sn01eh. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010678684561343246
# Wavelength shift: 6.675012813323099 Å
# Pixel shift: 0
# Error inesperado para sn2001ah. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010478093818429063
# Wavelength shift: 6.549627914884097 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010063451608060795
# Wavelength shift: 6.290444112679468 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010199174366415922
# Wavelength shift: 6.37528144876481 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010956701420988901
# Wavelength shift: 6.848795088639337 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010376354318883893
# Wavelength shift: 6.486032772693693 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009881931166589092
# Wavelength shift: 6.176979643741988 Å
# Pixel shift: 0
# Error inesperado para sn1999ac. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001017997159557027
# Wavelength shift: 6.36327821552857 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009847609376108376
# Wavelength shift: 6.155525841083157 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001080736165914336
# Wavelength shift: 6.755446060663908 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010410143499252208
# Wavelength shift: 6.507153652387682 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009898606591266306
# Wavelength shift: 6.187403088010671 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009817172273824308
# Wavelength shift: 6.136500272289595 Å
# Pixel shift: 0
# Error inesperado para sn2001V. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010926991252682033
# Wavelength shift: 6.830223910420229 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010053322190632587
# Wavelength shift: 6.2841124347713535 Å
# Pixel shift: 0
# Error inesperado para sn2005eq. Detalle: local variable 'spike_loc' referenced before assignment
# Error inesperado para sn08ds. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009893594765253172
# Wavelength shift: 6.1842703048795995 Å
# Pixel shift: 0
# Error inesperado para sn1997br. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010945578403786895
# Wavelength shift: 6.84184233318339 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010174612521151268
# Wavelength shift: 6.359928374992604 Å
# Pixel shift: 0
# Error inesperado para sn1999ac. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009028069471707811
# Wavelength shift: 5.643249321304091 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001064533833969686
# Wavelength shift: 6.654168817465099 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009378493718903303
# Wavelength shift: 5.862291875346419 Å
# Pixel shift: 0
# Error inesperado para sn1998es. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.000977880279165327
# Wavelength shift: 6.112516345836762 Å
# Pixel shift: 0
# Error inesperado para sn2005hj. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009028910675324554
# Wavelength shift: 5.643775139337961 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009595964649677358
# Wavelength shift: 5.998228211053626 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009036630415679205
# Wavelength shift: 5.648600580663325 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009832888874838248
# Wavelength shift: 6.146324376798657 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009580753151555164
# Wavelength shift: 5.9887198353457185 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009075843408528897
# Wavelength shift: 5.6731117672441105 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009080664790463109
# Wavelength shift: 5.676125507935103 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010841470080666586
# Wavelength shift: 6.776766491041067 Å
# Pixel shift: 0
# Error inesperado para sn1998es. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009298772430439667
# Wavelength shift: 5.812459836677936 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001048912242911459
# Wavelength shift: 6.556521658885631 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.000989483519823801
# Wavelength shift: 6.185045672484129 Å
# Pixel shift: 0
# Error inesperado para sn2003fa. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010352370250846293
# Wavelength shift: 6.471040854864588 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010895490502537142
# Wavelength shift: 6.810533478547412 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.000919119383615749
# Wavelength shift: 5.745214803720198 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009062783043943179
# Wavelength shift: 5.664948018192853 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009530424639526204
# Wavelength shift: 5.957260580159466 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010446002145009564
# Wavelength shift: 6.5295681097605724 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009415232949127367
# Wavelength shift: 5.8852567668635825 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009614482585920665
# Wavelength shift: 6.0098033691164305 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010856293827099911
# Wavelength shift: 6.786032491625267 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009815662100335154
# Wavelength shift: 6.135556295778955 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010028110468790089
# Wavelength shift: 6.26835313732438 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010716128460877415
# Wavelength shift: 6.698418178256917 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010427257935413405
# Wavelength shift: 6.517851513160004 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009413163766783828
# Wavelength shift: 5.883963366110252 Å
# Pixel shift: 0
# Error inesperado para sn1999gp. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009737602467538783
# Wavelength shift: 6.086762921826768 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010709617658928975
# Wavelength shift: 6.694348417961892 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010054457386007632
# Wavelength shift: 6.284822020641273 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009898784151053882
# Wavelength shift: 6.187514076761242 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009596856499759971
# Wavelength shift: 5.998785687088694 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009546922750330747
# Wavelength shift: 5.9675731893936215 Å
# Pixel shift: 0
# Procesando tipo: Ia-91bg
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009082745973206006
# Wavelength shift: 5.677426409876339 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009920377397023142
# Wavelength shift: 6.2010115438601225 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009844654286141805
# Wavelength shift: 6.153678678796634 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010517801260025662
# Wavelength shift: 6.574448170592468 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010955109573737342
# Wavelength shift: 6.847800059641151 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009482522280093923
# Wavelength shift: 5.927317860046132 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010637886699363123
# Wavelength shift: 6.6495109596154505 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001039747818375037
# Wavelength shift: 6.499236839902595 Å
# Pixel shift: 0
# Error inesperado para sn99by. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010728650835512231
# Wavelength shift: 6.706245641523621 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009145628299863646
# Wavelength shift: 5.716732780783743 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010868002786357863
# Wavelength shift: 6.793351506680776 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009911133237521471
# Wavelength shift: 6.19523322137409 Å
# Pixel shift: 0
# Error inesperado para sn1986G. Detalle: local variable 'spike_loc' referenced before assignment
# Error inesperado para sn2007al. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010378125040703618
# Wavelength shift: 6.48713961228312 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010445815916325348
# Wavelength shift: 6.529451702271784 Å
# Pixel shift: 0
# Error inesperado para sn1999by. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001045348013147684
# Wavelength shift: 6.5342424360036775 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.000905706975327466
# Wavelength shift: 5.661376764804898 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009221339171519009
# Wavelength shift: 5.764057995374015 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010073134473566055
# Wavelength shift: 6.296496660720008 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009407063483903895
# Wavelength shift: 5.880150212331381 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009586297360463799
# Wavelength shift: 5.992185399413304 Å
# Pixel shift: 0
# Error inesperado para sn2000cn. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010822849833731578
# Wavelength shift: 6.765127380796313 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009973171109225127
# Wavelength shift: 6.234011741907625 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010784771592022274
# Wavelength shift: 6.741325502404051 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009011488222093273
# Wavelength shift: 5.632884743813094 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010650502692561964
# Wavelength shift: 6.657396941804671 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009331497068295063
# Wavelength shift: 5.832915294065156 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010948935344432316
# Wavelength shift: 6.843940683564754 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010260500039728565
# Wavelength shift: 6.413614789617428 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010255184187271222
# Wavelength shift: 6.410291966187008 Å
# Pixel shift: 0
# Error inesperado para sn91bg. Detalle: local variable 'spike_loc' referenced before assignment
# Error inesperado para sn2003Y. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.000905974779893112
# Wavelength shift: 5.663050752735607 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010361665344388986
# Wavelength shift: 6.476851015108773 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010186920793894122
# Wavelength shift: 6.367622007836282 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010037821877819236
# Wavelength shift: 6.274423527299157 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009391742092509989
# Wavelength shift: 5.870573144736139 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010975247193453902
# Wavelength shift: 6.860387646517204 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009138620145031234
# Wavelength shift: 5.712352136048393 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010899867186144492
# Wavelength shift: 6.813269248013314 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009680315791753129
# Wavelength shift: 6.050954270236273 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001048700357494019
# Wavelength shift: 6.555197209354191 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010425189301816046
# Wavelength shift: 6.516558455415941 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010186467195898218
# Wavelength shift: 6.367338473622178 Å
# Pixel shift: 0
# Error inesperado para sn1991bg. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009763130276029694
# Wavelength shift: 6.1027197981437 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010055667239302726
# Wavelength shift: 6.285578273548698 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010017056837327556
# Wavelength shift: 6.261443753380851 Å
# Pixel shift: 0
# Error inesperado para sn1999by. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009068790421474435
# Wavelength shift: 5.668703098864565 Å
# Pixel shift: 0
# Error inesperado para sn2003Y. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.000948700437200465
# Wavelength shift: 5.930119517943481 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009158311360153269
# Wavelength shift: 5.7246606851486534 Å
# Pixel shift: 0
# Error inesperado para sn2000cn. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009027662045587984
# Wavelength shift: 5.6429946481226985 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009391034346844335
# Wavelength shift: 5.870130748356727 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001054460539870462
# Wavelength shift: 6.591202853072725 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010979824207879604
# Wavelength shift: 6.863248638408369 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009790882321294627
# Wavelength shift: 6.120066996356665 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009066990478930402
# Wavelength shift: 5.667577994037687 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.000989853632693985
# Wavelength shift: 6.187359167312694 Å
# Pixel shift: 0
# Error inesperado para sn91bg. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009817221361092241
# Wavelength shift: 6.136530955670169 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009955121271612176
# Wavelength shift: 6.222729182089256 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010588958766100725
# Wavelength shift: 6.618927175669047 Å
# Pixel shift: 0
# Error inesperado para sn2007al. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010063848355673065
# Wavelength shift: 6.290692110958689 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010523451091020149
# Wavelength shift: 6.577979756722264 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010398396784490323
# Wavelength shift: 6.499811037190125 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010540055310810181
# Wavelength shift: 6.588358692368975 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009815395918639565
# Wavelength shift: 6.135389911406562 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001013741487041234
# Wavelength shift: 6.336676934809916 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009250321852790939
# Wavelength shift: 5.782174437314338 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010010959694590179
# Wavelength shift: 6.257632562436605 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009974231072083233
# Wavelength shift: 6.234674301572054 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009670132766144295
# Wavelength shift: 6.044589083023663 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009549266254257041
# Wavelength shift: 5.9690380625852795 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010253368620984317
# Wavelength shift: 6.4091570952992205 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010986571198098264
# Wavelength shift: 6.867466034839757 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009560295412642107
# Wavelength shift: 5.975932148941851 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010679609038162382
# Wavelength shift: 6.675590683619568 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010957914820502132
# Wavelength shift: 6.849553558210374 Å
# Pixel shift: 0
# Error inesperado para sn1986G. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010866263688190686
# Wavelength shift: 6.792264434346834 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009756795536948764
# Wavelength shift: 6.098760090907161 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009834537116478004
# Wavelength shift: 6.147354656698922 Å
# Pixel shift: 0
# Error inesperado para sn91bg. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009144358047152774
# Wavelength shift: 5.715938773518847 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010219026336284792
# Wavelength shift: 6.387690482151198 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001004714089781738
# Wavelength shift: 6.280248643448799 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009638676272707779
# Wavelength shift: 6.024926315053996 Å
# Pixel shift: 0
# Procesando tipo: Ia-pec
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010621135152726815
# Wavelength shift: 6.639039933170385 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001090755970902705
# Wavelength shift: 6.818077676290494 Å
# Pixel shift: 0
# Error inesperado para sn00cx. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010034559559722624
# Wavelength shift: 6.272384323409302 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010168399344312321
# Wavelength shift: 6.356044653662212 Å
# Pixel shift: 0
# Error inesperado para sn2000cx. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009349453390634527
# Wavelength shift: 5.8441393995256705 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009341772628891007
# Wavelength shift: 5.839338322879987 Å
# Pixel shift: 0
# Error inesperado para sn2007if. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009210301236340518
# Wavelength shift: 5.757158422835299 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009317761381860075
# Wavelength shift: 5.824329416054934 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010892380643785626
# Wavelength shift: 6.808589573668983 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009768632953702225
# Wavelength shift: 6.106159401941409 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010533206313921779
# Wavelength shift: 6.584077533793133 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009383655229585761
# Wavelength shift: 5.86551822309961 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010451496165694663
# Wavelength shift: 6.533002302264249 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009862332444945633
# Wavelength shift: 6.164728910297869 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009398526383487176
# Wavelength shift: 5.874813857058138 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009219769363104786
# Wavelength shift: 5.763076742372374 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010931633407364478
# Wavelength shift: 6.833125620065153 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010274106463583157
# Wavelength shift: 6.422119868407909 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010659799961843751
# Wavelength shift: 6.663208462055911 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010180417889623652
# Wavelength shift: 6.363557184207505 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010714903653959958
# Wavelength shift: 6.697652578166297 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009188492297022407
# Wavelength shift: 5.743526130528403 Å
# Pixel shift: 0
# Error inesperado para sn2007if. Detalle: local variable 'spike_loc' referenced before assignment
# Error inesperado para sn2006gz. Detalle: local variable 'spike_loc' referenced before assignment
# Error inesperado para sn2007if. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009312855563554409
# Wavelength shift: 5.821262896029734 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010275435234028065
# Wavelength shift: 6.4229504538320565 Å
# Pixel shift: 0
# Error inesperado para sn2005cc. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009429032317330079
# Wavelength shift: 5.893882450957887 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010675448154741347
# Wavelength shift: 6.672989806143451 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009115392500702304
# Wavelength shift: 5.697833042181703 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009458376184960387
# Wavelength shift: 5.912224662613226 Å
# Pixel shift: 0
# Error inesperado para sn2000cx. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001093782704742817
# Wavelength shift: 6.8369971293834375 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001064440655558073
# Wavelength shift: 6.653586379536653 Å
# Pixel shift: 0
# Error inesperado para sn2008ae. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009837711606065264
# Wavelength shift: 6.149338960903152 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010544903981628028
# Wavelength shift: 6.5913894907459465 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010952751523752038
# Wavelength shift: 6.84632609402526 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010868776381096597
# Wavelength shift: 6.793835063879578 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009156708314702092
# Wavelength shift: 5.723658656400124 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001026315032436258
# Wavelength shift: 6.415271424738485 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001043474890255305
# Wavelength shift: 6.522533953338293 Å
# Pixel shift: 0
# Error inesperado para sn2000cx. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010639147691331638
# Wavelength shift: 6.650299178192278 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009177745450566378
# Wavelength shift: 5.736808511201347 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009609470729128145
# Wavelength shift: 6.006670566745836 Å
# Pixel shift: 0
# Error inesperado para sn2006gz. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001068371504209028
# Wavelength shift: 6.678157257121467 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009616905466093517
# Wavelength shift: 6.011317858668587 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009201683883123978
# Wavelength shift: 5.7517719032872305 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009020865309169837
# Wavelength shift: 5.638746156426994 Å
# Pixel shift: 0
# Error inesperado para sn2007if. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009527608601413701
# Wavelength shift: 5.95550033615415 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009462739050750595
# Wavelength shift: 5.914951794863004 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.00104084293977352
# Wavelength shift: 6.506082204914574 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010159051718576547
# Wavelength shift: 6.350201656689879 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010330717180314028
# Wavelength shift: 6.457505992736169 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009072738585260026
# Wavelength shift: 5.6711710099360575 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001047864274867447
# Wavelength shift: 6.549971039208134 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009107398961661694
# Wavelength shift: 5.692836455269395 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010619328765187838
# Wavelength shift: 6.637910799717736 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009854303286424592
# Wavelength shift: 6.159710058425218 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010174104085427936
# Wavelength shift: 6.359610562911117 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009855315742752127
# Wavelength shift: 6.160342922793522 Å
# Pixel shift: 0
# Error inesperado para sn2000cx. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009045194515114672
# Wavelength shift: 5.653953812434329 Å
# Pixel shift: 0
# Error inesperado para sn2007if. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009849596025688814
# Wavelength shift: 6.156767652406343 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009942195324257471
# Wavelength shift: 6.214649454317417 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009078479738070138
# Wavelength shift: 5.674759679341039 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010172142518468854
# Wavelength shift: 6.358384430187479 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010850113905607154
# Wavelength shift: 6.782169557486467 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009464971155516925
# Wavelength shift: 5.916347034869425 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009679532539269309
# Wavelength shift: 6.050464676191658 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010406809922125268
# Wavelength shift: 6.505069906032155 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009989762316043715
# Wavelength shift: 6.244382543429703 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009815788927667098
# Wavelength shift: 6.135635572778003 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010692040821110788
# Wavelength shift: 6.683361519998934 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001030459158622521
# Wavelength shift: 6.441175453679905 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009434588675815634
# Wavelength shift: 5.8973556094610196 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.000939283629111507
# Wavelength shift: 5.871257104419308 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009999264597658915
# Wavelength shift: 6.2503222124191655 Å
# Pixel shift: 0
# Error inesperado para sn2000cx. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010862421772287211
# Wavelength shift: 6.789862936509147 Å
# Pixel shift: 0
# Error inesperado para sn2007if. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010517686593368163
# Wavelength shift: 6.574376494965787 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009727908356664275
# Wavelength shift: 6.080703344551177 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010966443324147018
# Wavelength shift: 6.854884539829044 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009532557089166167
# Wavelength shift: 5.958593527919908 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010860591214368258
# Wavelength shift: 6.788718694679139 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.00109755201632394
# Wavelength shift: 6.860558273976547 Å
# Pixel shift: 0
# Error inesperado para sn2007if. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010153689522485665
# Wavelength shift: 6.346849864864904 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010135505828587816
# Wavelength shift: 6.3354836344023 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001051877824511579
# Wavelength shift: 6.575058862663909 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009045830376099061
# Wavelength shift: 5.654351275267312 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010846756953030833
# Wavelength shift: 6.7800711996473595 Å
# Pixel shift: 0
# Error inesperado para sn2007if. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009936614271950884
# Wavelength shift: 6.2111608602453385 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010115855463188124
# Wavelength shift: 6.323200619572528 Å
# Pixel shift: 0
# Error inesperado para sn2006gz. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010208778070258722
# Wavelength shift: 6.3812845145766905 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010572518750588775
# Wavelength shift: 6.608650880535211 Å
# Pixel shift: 0
# Error inesperado para sn2000cx. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009691519946625574
# Wavelength shift: 6.057957743080369 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010171706623851944
# Wavelength shift: 6.358111961969468 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009635853804818608
# Wavelength shift: 6.023162051935521 Å
# Pixel shift: 0
# Error inesperado para sn2007if. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001022541924933747
# Wavelength shift: 6.3916865526686815 Å
# Pixel shift: 0
# Error inesperado para sn2007if. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010589752593352425
# Wavelength shift: 6.619423379770424 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009312559204767106
# Wavelength shift: 5.821077648615483 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009908178272626592
# Wavelength shift: 6.1933861372671535 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010274922244729785
# Wavelength shift: 6.422629795410184 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010574897172700025
# Wavelength shift: 6.610137580322706 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010129901440757085
# Wavelength shift: 6.331980453803035 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010578602715406338
# Wavelength shift: 6.612453834249196 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009553797906866365
# Wavelength shift: 5.971870699794386 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010635952947102973
# Wavelength shift: 6.648302213253467 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010578966423860654
# Wavelength shift: 6.612681180471376 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001043701381128887
# Wavelength shift: 6.5239496983905765 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010686460151651167
# Wavelength shift: 6.679873165236144 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010722235733103631
# Wavelength shift: 6.702235700923708 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001079479005790078
# Wavelength shift: 6.747587826918341 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009804612056738958
# Wavelength shift: 6.128649154532421 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009464478412116097
# Wavelength shift: 5.916039031716479 Å
# Pixel shift: 0
# Error inesperado para sn2007if. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010221729163659946
# Wavelength shift: 6.3893799605937645 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010327658026563474
# Wavelength shift: 6.455593782447947 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001066262246880354
# Wavelength shift: 6.6649727495965765 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009839003356784956
# Wavelength shift: 6.150146406104481 Å
# Pixel shift: 0
# Error inesperado para sn2006gz. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010126275731909265
# Wavelength shift: 6.329714102280284 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0010685398159560394
# Wavelength shift: 6.679209337142633 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009168348082870386
# Wavelength shift: 5.73093442161457 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009910638397987355
# Wavelength shift: 6.194923907973942 Å
# Pixel shift: 0
# Error inesperado para sn2006gz. Detalle: local variable 'spike_loc' referenced before assignment
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009386071998201012
# Wavelength shift: 5.867028892450405 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.0009212623640159017
# Wavelength shift: 5.758610106809776 Å
# Pixel shift: 0
# Central wavelength: 6250.781896383187 Å
# Redshift variation: 0.001010303209203423
# Wavelength shift: 6.315185009946592 Å
# Pixel shift: 0
